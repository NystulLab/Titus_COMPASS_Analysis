# %%
# Core Python
import os
from pathlib import Path

# Arrays / numerics
import numpy as np

# TIFF IO
from tifffile import imread, imwrite

# Curve fitting
from scipy.optimize import curve_fit

# Optional (only if you want tabular outputs, logging, or to later expand with masks/props)
import pandas as pd

# %%
images_dir   = Path(r"/media/el_tito/Vector NysL/20250605 histone compass/tiffed/")     # input TIFFs (Z,C,Y,X)
out_dir      = Path(r"/media/el_tito/Vector NysL/20250605 histone compass/deattenuated/")  # output folder
image_exts   = [".tif", ".tiff"]

channel_idx  = 0            # which channel to correct (0 = C1)
overwrite    = False        # skip if output exists

# Output dtype: "float32" (no scaling) or "uint16" (scaled)
output_dtype = "float32"
# If uint16, robust scaling window for the corrected channel:
p_low, p_high = 1.0, 99.9
# =========================

out_dir.mkdir(parents=True, exist_ok=True)

def linear(z, m, b): return m*z + b
def hyperbolic(z, a, b, c): return a / (z + b) + c

def _fit_profile(z, y):
    # Linear fit
    m0, b0 = np.polyfit(z, y, 1)
    p_lin, _ = curve_fit(linear, z, y, p0=[m0, b0], maxfev=10000)
    ylin = linear(z, *p_lin)

    # Hyperbolic fit with safe bounds
    eps = 1e-6
    b_lower = -float(np.min(z)) + eps
    a0 = (y[0] - y[-1]) * (z[-1] + 1.0) if z[-1] > 0 else 1.0
    b0 = b_lower + 1.0
    c0 = float(np.median(y[-max(3, len(y)//10):]))
    bounds = ([-np.inf, b_lower, -np.inf], [np.inf, np.inf, np.inf])

    try:
        p_hyp, _ = curve_fit(hyperbolic, z, y, p0=[a0, b0, c0], bounds=bounds, maxfev=20000)
        yhyp = hyperbolic(z, *p_hyp)
    except Exception:
        yhyp = None

    def metrics(y_true, y_pred, k):
        rss = float(np.sum((y_true - y_pred) ** 2))
        tss = float(np.sum((y_true - np.mean(y_true)) ** 2))
        r2  = 1.0 - (rss / tss) if tss > 0 else np.nan
        n   = len(y_true)
        aic = n * np.log(rss / n) + 2 * k if rss > 0 else -np.inf
        return r2, aic

    r2_lin, aic_lin = metrics(y, ylin, 2)
    if yhyp is not None:
        r2_hyp, aic_hyp = metrics(y, yhyp, 3)
        if (aic_hyp + 2 < aic_lin) or (abs(aic_hyp - aic_lin) <= 2 and r2_hyp > r2_lin):
            return "hyperbolic", yhyp
    return "linear", ylin

def _correction_factors(z, y):
    """Return per-Z multiplicative factors: corrected = raw * factor[z]."""
    model, yfit = _fit_profile(z, y)
    # Normalize to median of top quartile (robust bright-ish target)
    q75 = np.percentile(y, 75)
    target = float(np.median(y[y >= q75])) if np.any(y >= q75) else float(np.median(y))
    denom = np.maximum(yfit, 1e-9)
    factors = target / denom
    return model, factors

def _save_corrected_single(stack_zcyx: np.ndarray, path: Path):
    if output_dtype == "float32":
        imwrite(path, stack_zcyx.astype(np.float32), imagej=False)
    elif output_dtype == "uint16":
        # Scale ONLY the corrected channel robustly; keep others as-is but cast
        out = stack_zcyx.astype(np.float32, copy=True)
        ch = out[:, channel_idx, :, :]
        lo = np.percentile(ch, p_low)
        hi = np.percentile(ch, p_high)
        if hi <= lo: hi = lo + 1e-6
        out[:, channel_idx, :, :] = np.clip((ch - lo) / (hi - lo), 0, 1) * 65535.0
        imwrite(path, out.astype(np.uint16), imagej=False)
    else:
        raise ValueError("output_dtype must be 'float32' or 'uint16'")

def _process_one(img_path: Path):
    out_path = out_dir / f"{img_path.stem}_corrC{channel_idx}.tif"
    if out_path.exists() and not overwrite:
        print(f"Skipping {img_path.name}: exists (set overwrite=True to redo).")
        return

    img = imread(img_path)  # expect Z,C,Y,X
    if img.ndim != 4:
        print(f"⚠️  {img_path.name} is not ZCYX (got {img.shape}); skipping.")
        return
    if channel_idx >= img.shape[1]:
        print(f"⚠️  channel_idx {channel_idx} out of range for {img_path.name} (shape {img.shape}); skipping.")
        return

    img_f = img.astype(np.float32, copy=False)
    ch = img_f[:, channel_idx, :, :]  # Z,Y,X

    z = np.arange(ch.shape[0], dtype=float)
    z_means = ch.mean(axis=(1, 2))
    model, factors = _correction_factors(z, z_means)
    ch_corr = ch * factors[:, None, None]

    corrected = img_f.copy()
    corrected[:, channel_idx, :, :] = ch_corr

    _save_corrected_single(corrected, out_path)
    print(f"✓ {img_path.name}: model={model}; wrote {out_path.name}")

# Run
files = [p for p in images_dir.iterdir() if p.suffix.lower() in image_exts]
if not files:
    print(f"No images found in {images_dir}")
for p in sorted(files):
    try:
        _process_one(p)
    except Exception as e:
        print(f"❌ Error on {p.name}: {e}")
# Out:
# ✓ 20250605 c13-01(1)-ApoTome RAW Convert-01.tiff: model=hyperbolic; wrote 20250605 c13-01(1)-ApoTome RAW Convert-01_corrC0.tif
# ✓ 20250605 c13-01(10)-ApoTome RAW Convert-10.tiff: model=hyperbolic; wrote 20250605 c13-01(10)-ApoTome RAW Convert-10_corrC0.tif
# ✓ 20250605 c13-01(11)-ApoTome RAW Convert-11.tiff: model=hyperbolic; wrote 20250605 c13-01(11)-ApoTome RAW Convert-11_corrC0.tif
# ✓ 20250605 c13-01(12)-ApoTome RAW Convert-12.tiff: model=hyperbolic; wrote 20250605 c13-01(12)-ApoTome RAW Convert-12_corrC0.tif
# ✓ 20250605 c13-01(13)-ApoTome RAW Convert-13.tiff: model=hyperbolic; wrote 20250605 c13-01(13)-ApoTome RAW Convert-13_corrC0.tif
# ✓ 20250605 c13-01(14)-ApoTome RAW Convert-14.tiff: model=hyperbolic; wrote 20250605 c13-01(14)-ApoTome RAW Convert-14_corrC0.tif
# ✓ 20250605 c13-01(15)-ApoTome RAW Convert-15.tiff: model=hyperbolic; wrote 20250605 c13-01(15)-ApoTome RAW Convert-15_corrC0.tif
# ✓ 20250605 c13-01(16)-ApoTome RAW Convert-16.tiff: model=hyperbolic; wrote 20250605 c13-01(16)-ApoTome RAW Convert-16_corrC0.tif
# ✓ 20250605 c13-01(17)-ApoTome RAW Convert-17.tiff: model=hyperbolic; wrote 20250605 c13-01(17)-ApoTome RAW Convert-17_corrC0.tif
# ✓ 20250605 c13-01(18)-ApoTome RAW Convert-18.tiff: model=hyperbolic; wrote 20250605 c13-01(18)-ApoTome RAW Convert-18_corrC0.tif
# ✓ 20250605 c13-01(19)-ApoTome RAW Convert-19.tiff: model=hyperbolic; wrote 20250605 c13-01(19)-ApoTome RAW Convert-19_corrC0.tif
# ✓ 20250605 c13-01(2)-ApoTome RAW Convert-02.tiff: model=hyperbolic; wrote 20250605 c13-01(2)-ApoTome RAW Convert-02_corrC0.tif
# ✓ 20250605 c13-01(20)-ApoTome RAW Convert-20.tiff: model=hyperbolic; wrote 20250605 c13-01(20)-ApoTome RAW Convert-20_corrC0.tif
# ✓ 20250605 c13-01(21)-ApoTome RAW Convert-21.tiff: model=hyperbolic; wrote 20250605 c13-01(21)-ApoTome RAW Convert-21_corrC0.tif
# ✓ 20250605 c13-01(3)-ApoTome RAW Convert-03.tiff: model=hyperbolic; wrote 20250605 c13-01(3)-ApoTome RAW Convert-03_corrC0.tif
# ✓ 20250605 c13-01(4)-ApoTome RAW Convert-04.tiff: model=hyperbolic; wrote 20250605 c13-01(4)-ApoTome RAW Convert-04_corrC0.tif
# ✓ 20250605 c13-01(5)-ApoTome RAW Convert-05.tiff: model=hyperbolic; wrote 20250605 c13-01(5)-ApoTome RAW Convert-05_corrC0.tif
# ✓ 20250605 c13-01(6)-ApoTome RAW Convert-06.tiff: model=hyperbolic; wrote 20250605 c13-01(6)-ApoTome RAW Convert-06_corrC0.tif
# ✓ 20250605 c13-01(7)-ApoTome RAW Convert-07.tiff: model=hyperbolic; wrote 20250605 c13-01(7)-ApoTome RAW Convert-07_corrC0.tif
# ✓ 20250605 c13-01(8)-ApoTome RAW Convert-08.tiff: model=hyperbolic; wrote 20250605 c13-01(8)-ApoTome RAW Convert-08_corrC0.tif
# ✓ 20250605 c13-01(9)-ApoTome RAW Convert-09.tiff: model=hyperbolic; wrote 20250605 c13-01(9)-ApoTome RAW Convert-09_corrC0.tif
# ✓ 20250605 c23_001.tiff: model=hyperbolic; wrote 20250605 c23_001_corrC0.tif
# ✓ 20250605 c23_002.tiff: model=hyperbolic; wrote 20250605 c23_002_corrC0.tif
# ✓ 20250605 c23_003.tiff: model=hyperbolic; wrote 20250605 c23_003_corrC0.tif
# ✓ 20250605 c23_004.tiff: model=hyperbolic; wrote 20250605 c23_004_corrC0.tif
# ✓ 20250605 c23_005.tiff: model=hyperbolic; wrote 20250605 c23_005_corrC0.tif
# ✓ 20250605 c23_006.tiff: model=hyperbolic; wrote 20250605 c23_006_corrC0.tif
# ✓ 20250605 c23_007.tiff: model=hyperbolic; wrote 20250605 c23_007_corrC0.tif
# ✓ 20250605 c23_008.tiff: model=hyperbolic; wrote 20250605 c23_008_corrC0.tif
# ✓ 20250605 c23_009.tiff: model=hyperbolic; wrote 20250605 c23_009_corrC0.tif
# ✓ 20250605 c23_010.tiff: model=hyperbolic; wrote 20250605 c23_010_corrC0.tif
# ✓ 20250605 c23_011.tiff: model=hyperbolic; wrote 20250605 c23_011_corrC0.tif
# ✓ 20250605 c23_012.tiff: model=hyperbolic; wrote 20250605 c23_012_corrC0.tif
# ✓ 20250605 c23_013.tiff: model=hyperbolic; wrote 20250605 c23_013_corrC0.tif
# ✓ 20250605 c23_014.tiff: model=hyperbolic; wrote 20250605 c23_014_corrC0.tif
# ✓ 20250605 c23_015.tiff: model=hyperbolic; wrote 20250605 c23_015_corrC0.tif
# ✓ 20250605 c23_016.tiff: model=hyperbolic; wrote 20250605 c23_016_corrC0.tif
# ✓ 20250605 c23_017.tiff: model=hyperbolic; wrote 20250605 c23_017_corrC0.tif
# ✓ 20250605 c23_018.tiff: model=hyperbolic; wrote 20250605 c23_018_corrC0.tif
# ✓ 20250605 c23_019.tiff: model=hyperbolic; wrote 20250605 c23_019_corrC0.tif
# ✓ 20250605 c23_020.tiff: model=hyperbolic; wrote 20250605 c23_020_corrC0.tif
# ✓ 20250605 c23_021.tiff: model=hyperbolic; wrote 20250605 c23_021_corrC0.tif
# ✓ 20250605 wg3_001.tiff: model=hyperbolic; wrote 20250605 wg3_001_corrC0.tif
# ✓ 20250605 wg3_002.tiff: model=hyperbolic; wrote 20250605 wg3_002_corrC0.tif
# ✓ 20250605 wg3_003.tiff: model=hyperbolic; wrote 20250605 wg3_003_corrC0.tif
# ✓ 20250605 wg3_004.tiff: model=hyperbolic; wrote 20250605 wg3_004_corrC0.tif
# ✓ 20250605 wg3_005.tiff: model=hyperbolic; wrote 20250605 wg3_005_corrC0.tif
# ✓ 20250605 wg3_006.tiff: model=hyperbolic; wrote 20250605 wg3_006_corrC0.tif
# ✓ 20250605 wg3_007.tiff: model=hyperbolic; wrote 20250605 wg3_007_corrC0.tif
# ✓ 20250605 wg3_008.tiff: model=hyperbolic; wrote 20250605 wg3_008_corrC0.tif
# ✓ 20250605 wg3_009.tiff: model=hyperbolic; wrote 20250605 wg3_009_corrC0.tif
# ✓ 20250605 wg3_010.tiff: model=hyperbolic; wrote 20250605 wg3_010_corrC0.tif
# ✓ 20250605 wg3_011.tiff: model=hyperbolic; wrote 20250605 wg3_011_corrC0.tif
# ✓ 20250605 wg3_012.tiff: model=hyperbolic; wrote 20250605 wg3_012_corrC0.tif
# ✓ 20250605 wg3_013.tiff: model=hyperbolic; wrote 20250605 wg3_013_corrC0.tif
# ✓ 20250605 wg3_014.tiff: model=hyperbolic; wrote 20250605 wg3_014_corrC0.tif
# ✓ 20250605 wg3_015.tiff: model=hyperbolic; wrote 20250605 wg3_015_corrC0.tif
# ✓ 20250605 wg3_016.tiff: model=hyperbolic; wrote 20250605 wg3_016_corrC0.tif
# ✓ 20250605 wg3_017.tiff: model=hyperbolic; wrote 20250605 wg3_017_corrC0.tif
# ✓ 20250605 wg3_018.tiff: model=hyperbolic; wrote 20250605 wg3_018_corrC0.tif
# ✓ 20250605 wg3_019.tiff: model=hyperbolic; wrote 20250605 wg3_019_corrC0.tif
# ✓ 20250605 wg3_020.tiff: model=hyperbolic; wrote 20250605 wg3_020_corrC0.tif
# ✓ 20250605 wg3_021.tiff: model=hyperbolic; wrote 20250605 wg3_021_corrC0.tif
# ✓ 20250605 wr3_001.tiff: model=hyperbolic; wrote 20250605 wr3_001_corrC0.tif
# ✓ 20250605 wr3_002.tiff: model=linear; wrote 20250605 wr3_002_corrC0.tif
# ✓ 20250605 wr3_003.tiff: model=hyperbolic; wrote 20250605 wr3_003_corrC0.tif
# ✓ 20250605 wr3_004.tiff: model=hyperbolic; wrote 20250605 wr3_004_corrC0.tif
# ✓ 20250605 wr3_005.tiff: model=hyperbolic; wrote 20250605 wr3_005_corrC0.tif
# ✓ 20250605 wr3_006.tiff: model=hyperbolic; wrote 20250605 wr3_006_corrC0.tif
# ✓ 20250605 wr3_007.tiff: model=linear; wrote 20250605 wr3_007_corrC0.tif
# ✓ 20250605 wr3_008.tiff: model=hyperbolic; wrote 20250605 wr3_008_corrC0.tif
# ✓ 20250605 wr3_009.tiff: model=hyperbolic; wrote 20250605 wr3_009_corrC0.tif
# ✓ 20250605 wr3_010.tiff: model=hyperbolic; wrote 20250605 wr3_010_corrC0.tif
# ✓ 20250605 wr3_011.tiff: model=hyperbolic; wrote 20250605 wr3_011_corrC0.tif
# ✓ 20250605 wr3_012.tiff: model=hyperbolic; wrote 20250605 wr3_012_corrC0.tif
# ✓ 20250605 wr3_013.tiff: model=linear; wrote 20250605 wr3_013_corrC0.tif
# ✓ 20250605 wr3_014.tiff: model=hyperbolic; wrote 20250605 wr3_014_corrC0.tif
# ✓ 20250605 wr3_015.tiff: model=hyperbolic; wrote 20250605 wr3_015_corrC0.tif
# ✓ 20250605 wr3_016.tiff: model=hyperbolic; wrote 20250605 wr3_016_corrC0.tif
# ✓ 20250605 wr3_017.tiff: model=hyperbolic; wrote 20250605 wr3_017_corrC0.tif
# ✓ 20250605 wr3_018.tiff: model=hyperbolic; wrote 20250605 wr3_018_corrC0.tif
# ✓ 20250605 wr3_019.tiff: model=hyperbolic; wrote 20250605 wr3_019_corrC0.tif
# ✓ 20250605 wr3_020.tiff: model=hyperbolic; wrote 20250605 wr3_020_corrC0.tif
# ✓ 20250605 wr3_021.tiff: model=hyperbolic; wrote 20250605 wr3_021_corrC0.tif
